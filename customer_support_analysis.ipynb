# %%
import os 

os.getcwd()

# %%
import pandas as pd   
import numpy as np   

df_agents = pd.read_csv('/Workspace/Users/rohanksingh088@outlook.com/Drafts/sample_data/agents.csv')
df_crm_tickets = pd.read_csv('/Workspace/Users/rohanksingh088@outlook.com/Drafts/sample_data/crm_tickets.csv')
df_escalations = pd.read_csv('/Workspace/Users/rohanksingh088@outlook.com/Drafts/sample_data/escalations.csv')
df_helpdesk_tickets = pd.read_csv('/Workspace/Users/rohanksingh088@outlook.com/Drafts/sample_data/helpdesk_tickets.csv')
df_region_config = pd.read_csv('/Workspace/Users/rohanksingh088@outlook.com/Drafts/sample_data/region_config.csv')
df_support_tickets = pd.read_csv('/Workspace/Users/rohanksingh088@outlook.com/Drafts/sample_data/support_tickets.csv')

# %%
# %sql
-- Extract and transform raw ticket data 

create or replace table gold.tickets_clean;

# %%
# %sql
